# %% [markdown]
# 1. Correlation Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# Correlation analysis

# %%
correlation_matrix = df.corr()
# Out:
# <ipython-input-9-68bbfff3c4eb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Assuming 'sales' is your target variable

if 'sales' in correlation_matrix:
    sales_correlation = correlation_matrix['sales']

# %% [markdown]
# Visualize the correlation with a bar chart

# %%
sales_correlation = df.corr()
# Out:
# <ipython-input-11-1690d5a80b9a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales_correlation = df.corr()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# 2. Scatter Plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# Assuming df is your DataFrame with columns 'sales' and 'another_variable'
data = {'sales': [100, 150, 200, 120, 180],
        'another_variable': [30, 45, 60, 35, 55]}
df = pd.DataFrame(data)

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['another_variable'], df['sales'], color='blue', alpha=0.7)
plt.title('Scatter Plot of Sales vs Another Variable')
plt.xlabel('Another Variable')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Pair Plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
df = pd.DataFrame(data)

# %%
# Import the iris dataset
iris = datasets.load_iris()

# Convert the iris dataset to a DataFrame
iris = pd.DataFrame(iris.data, columns=iris.feature_names)

# Create the pair plot
sns.pairplot(iris)

# %% [markdown]
# 4. Category-wise Sales Trends

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# Sample data (replace this with your actual data)
data = {
    'Date': ['2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01'],
    'CategoryA': [100, 120, 90, 110],
    'CategoryB': [80, 85, 95, 100],
    'CategoryC': [70, 60, 80, 75]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Convert the 'Date' column to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Set 'Date' as the index
df.set_index('Date', inplace=True)

# Plotting line charts for each category
plt.figure(figsize=(10, 6))

for column in df.columns:
    plt.plot(df.index, df[column], label=column)

# Customize the plot
plt.title('Sales Trends Across Different Categories')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Heatmaps

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# Creating a random dataset
np.random.seed(42)
data = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

# %%
correlation_matrix = data.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# 6. Sales by Region

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
regions = ['North', 'South', 'East', 'West']
sales = [500000, 750000, 600000, 900000]

# %%
plt.bar(regions, sales, color='blue')
plt.title('Sales Across Different Regions (Bar Chart)')
plt.xlabel('Regions')
plt.ylabel('Sales Amount')
plt.show()

# %% [markdown]
# Stacked Bar Chart

# %%
regions = ['North', 'South', 'East', 'West']
product_a = [200000, 150000, 180000, 250000]
product_b = [300000, 200000, 150000, 350000]

# %%
plt.bar(regions, product_a, label='Product A', color='blue')
plt.bar(regions, product_b, label='Product B', color='orange', bottom=product_a)

plt.title('Sales Breakdown by Product Across Different Regions (Stacked Bar Chart)')
plt.xlabel('Regions')
plt.ylabel('Sales Amount')
plt.legend()
plt.show()

# %% [markdown]
# 7. Customer Segment Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# Sample Data (Replace this with your actual data)
data = {
    'Date': ['2022-01-01', '2022-02-01', '2022-03-01', '2022-01-01', '2022-02-01', '2022-03-01'],
    'Segment': ['A', 'A', 'A', 'B', 'B', 'B'],
    'Sales': [100, 120, 150, 80, 90, 110]
}

# %%
# Create a DataFrame
df = pd.DataFrame(data)

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Plotting a Line Chart
plt.figure(figsize=(10, 6))
sns.lineplot(x='Date', y='Sales', hue='Segment', data=df)
plt.title('Sales Trends for Different Customer Segments (Line Chart)')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Plotting a Bar Chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Segment', y='Sales', data=df)
plt.title('Sales Trends for Different Customer Segments (Bar Chart)')
plt.xlabel('Customer Segment')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# 8. Sales vs. Quantity

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# Example data
sales = np.random.randint(100, 1000, size=50)
quantity_sold = np.random.randint(10, 100, size=50)

# %%
# Scatter plot
plt.scatter(quantity_sold, sales, c='blue', alpha=0.7)

# Title and labels
plt.title('Relationship between Sales and Quantity Sold')
plt.xlabel('Quantity Sold')
plt.ylabel('Sales')

# Display the plot
plt.show()

# %% [markdown]
# 9. Customer Segment vs. Quantity

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# data
segments = ['Segment A', 'Segment B', 'Segment C']
quantity_sold = [100, 150, 80]

# Create a bar chart
plt.bar(segments, quantity_sold, color='skyblue')

# Customize the chart
plt.xlabel('Customer Segment')
plt.ylabel('Quantity Sold')
plt.title('Quantity Sold Across Customer Segments')

# Show the chart
plt.show()

# %% [markdown]
# 10. Discount Impact on Sales

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# Generate synthetic data
np.random.seed(42)
discounts = np.arange(0, 51, 5)
sales = np.random.randint(1000, 5000, len(discounts))

# %%
# Create a DataFrame
data = pd.DataFrame({'Discount': discounts, 'Sales': sales})

# %%
# Display the DataFrame
print(data)
# Out:
#     Discount  Sales
# 0          0   4174
# 1          5   4507
# 2         10   1860
# 3         15   2294
# 4         20   2130
# 5         25   2095
# 6         30   4772
# 7         35   4092
# 8         40   2638
# 9         45   3169
# 10        50   1466

# %%
# Plot a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Discount', y='Sales', data=data, palette='viridis')
plt.title('Impact of Discounts on Sales (Bar Chart)')
plt.xlabel('Discount (%)')
plt.ylabel('Sales')
plt.show()

# %%
# Plot a line chart
plt.figure(figsize=(10, 6))
sns.lineplot(x='Discount', y='Sales', data=data, marker='o', color='b')
plt.title('Impact of Discounts on Sales (Line Chart)')
plt.xlabel('Discount (%)')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# 11. Shipping Mode vs. Sales

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# data (replace this with your actual dataset)
data = {
    'Shipping Mode': ['Standard', 'Express', 'Standard', 'Express', 'Express', 'Standard', 'Express', 'Standard'],
    'Sales': [200, 300, 150, 250, 400, 180, 320, 220]
}

# %%
df = pd.DataFrame(data)

# %%
# Categorical plot using seaborn
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")
sns.catplot(x='Shipping Mode', y='Sales', data=df, kind='bar', ci=None, palette='viridis')

plt.title('Relationship between Shipping Modes and Sales')
plt.xlabel('Shipping Mode')
plt.ylabel('Sales')
plt.show()
# Out:
# <ipython-input-61-72641b1a9c97>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x='Shipping Mode', y='Sales', data=df, kind='bar', ci=None, palette='viridis')

# %% [markdown]
# 12. Product-wise Sales Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# Create a synthetic dataset
data = {'Product': ['A', 'B', 'C', 'D', 'A', 'B', 'C', 'D'],
        'Category': ['Electronics', 'Electronics', 'Clothing', 'Clothing', 'Electronics', 'Electronics', 'Clothing', 'Clothing'],
        'Sales': [100, 150, 80, 120, 120, 90, 60, 110]}

# %%
df = pd.DataFrame(data)

# %%
# Visualize using a bar chart
plt.figure(figsize=(10, 6))
df_grouped = df.groupby('Category')['Sales'].sum().reset_index()
plt.bar(df_grouped['Category'], df_grouped['Sales'], color='skyblue')
plt.title('Total Sales by Category (Bar Chart)')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# Visualize using a line chart (assuming a time dimension)
# For simplicity, let's assume sales occurred in two different months.
df['Date'] = pd.to_datetime(['2024-01-01', '2024-02-01'] * 4, format='%Y-%m-%d')
df_time = df.groupby(['Date', 'Category'])['Sales'].sum().reset_index()

plt.figure(figsize=(10, 6))
for category in df_time['Category'].unique():
    plt.plot(df_time[df_time['Category'] == category]['Date'], df_time[df_time['Category'] == category]['Sales'], marker='o', label=category)

plt.title('Sales Trend Over Time by Category (Line Chart)')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.legend()
plt.show()

# %% [markdown]
# 13. Region-wise Product Sales

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# Sample data
regions = ['North', 'South', 'East', 'West']
products = ['Product A', 'Product B', 'Product C']
sales = np.array([
    [1000, 1200, 800],
    [800, 1100, 750],
    [1200, 900, 950],
    [950, 1300, 800]
])

# %%
# Create grouped bar chart
bar_width = 0.2
r1 = np.arange(len(regions))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

plt.bar(r1, sales[:, 0], width=bar_width, label='Product A')
plt.bar(r2, sales[:, 1], width=bar_width, label='Product B')
plt.bar(r3, sales[:, 2], width=bar_width, label='Product C')

# Customize chart
plt.xlabel('Region')
plt.ylabel('Sales')
plt.xticks([r + bar_width for r in range(len(regions))], regions)
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 14. Document Findings

# %% [markdown]
# Univariate Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %% [markdown]
# Descriptive statistics

# %%
df = pd.DataFrame(data)
df.describe()
# Out:
#             Sales
# count    8.000000
# mean   103.750000
# std     27.742438
# min     60.000000
# 25%     87.500000
# 50%    105.000000
# 75%    120.000000
# max    150.000000

# %% [markdown]
# Histograms for numerical variables

# %%
data = pd.DataFrame(data)
data.hist(figsize=(8, 6))
plt.show()

# %% [markdown]
# Box plots for numerical variables

# %%
# Assuming df is your DataFrame with columns 'Category' and 'Value'
df['Value'] = [0,1, 2, 3, 4, 5,6, 7]

# Group the DataFrame by 'Category' and extract the 'Value' column
grouped_df = df.groupby('Category')['Value']

# Convert the grouped data to a list for boxplot
data_to_plot = [group.values for name, group in grouped_df]

# Create a boxplot using Matplotlib
plt.boxplot(data_to_plot, labels=grouped_df.groups.keys())
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Boxplot of Values by Category')
plt.show()

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# Scatter plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
# data
import pandas as pd
data = pd.DataFrame({'variable1': [1, 2, 3, 4, 5],
                     'variable2': [2, 3, 4, 5, 6]})

# Check the column names and data types
print(data.columns)
print(data.dtypes)

# Plotting
sns.scatterplot(x='variable1', y='variable2', data=data)
plt.show()
# Out:
# Index(['variable1', 'variable2'], dtype='object')
# variable1    int64
# variable2    int64
# dtype: object

# %% [markdown]
# Correlation matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Pairplot for multiple variables

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('/content/train.csv')

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# **Key Findings and Trends**

# %% [markdown]
# **Univariate:**
#
#
# 1.   Identify central tendencies and spread for
# numerical variables.
#
# 2.
# Spot outliers and distribution patterns.

# %% [markdown]
# **Bivariate:**
#
# 1.   Examine relationships between pairs of variables.
# 2.   Understand the strength and direction of correlations.
#
# 3.   Identify potential predictors through regression analysis.
